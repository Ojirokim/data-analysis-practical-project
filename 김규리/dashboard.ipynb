# %%
import pandas as pd
df = pd.read_csv("course_final.csv", encoding = "utf-8", index_col= 0)

# %%
import pandas as pd

funnel = pd.DataFrame({
    "Stage": ["Registered", "Viewed", "Explored"],
    "Users": [533993, 325361, 37584]
})
funnel.to_csv("funnel.csv", index=False, encoding="utf-8")
